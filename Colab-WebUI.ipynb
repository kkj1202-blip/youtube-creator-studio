# %% [markdown]
# <a href="https://colab.research.google.com/github/kkj1202-blip/youtube-creator-studio/blob/main/Colab-WebUI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # GPT-SoVITS WebUI

# %% [markdown]
# ## Env Setup (Run Once Only)
# ## 环境配置, 只需运行一次

# %% [markdown]
# ### 1.

# %%
# %%writefile /content/setup.sh
# set -e
#
# cd /content
#
# git clone https://github.com/RVC-Boss/GPT-SoVITS.git
#
# cd GPT-SoVITS
#
# if conda env list | awk '{print $1}' | grep -Fxq "GPTSoVITS"; then
#     :
# else
#     conda create -n GPTSoVITS python=3.10 -y
# fi
#
# source activate GPTSoVITS
#
# pip install ipykernel
#
# bash install.sh --device CU126 --source HF --download-uvr5
# Out:
# Writing /content/setup.sh

# %%
# !pip install torchcodec

# %% [markdown]
# ### 2.

# %%
# %pip install -q condacolab
import condacolab
condacolab.install_from_url("https://repo.anaconda.com/archive/Anaconda3-2024.10-1-Linux-x86_64.sh")
# !cd /content && bash setup.sh
# Out:
# ⏬ Downloading https://repo.anaconda.com/archive/Anaconda3-2024.10-1-Linux-x86_64.sh...
# 📦 Installing...
# 📌 Adjusting configuration...
# 🩹 Patching environment...
# ⏲ Done in 0:01:50
# 🔁 Restarting kernel...
# Cloning into 'GPT-SoVITS'...
# remote: Enumerating objects: 5816, done.
# remote: Counting objects: 100% (23/23), done.
# remote: Compressing objects: 100% (17/17), done.
# remote: Total 5816 (delta 13), reused 6 (delta 6), pack-reused 5793 (from 2)
# Receiving objects: 100% (5816/5816), 14.06 MiB | 6.78 MiB/s, done.
# Resolving deltas: 100% (3337/3337), done.
# Channels:
#  - defaults
# Platform: linux-64
# done
# done
#
# ## Package Plan ##
#
#   environment location: /usr/local/envs/GPTSoVITS
#
#   added / updated specs:
#     - python=3.10
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     ca-certificates-2025.12.2  |       h06a4308_0         125 KB
# ...

# %% [markdown]
# ## Launch WebUI
# ## 启动 WebUI

# %%
# !cd /content/GPT-SoVITS && source activate GPTSoVITS && export is_share=True && python webui.py
# Out:
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# Running on local URL:  http://0.0.0.0:9874
# Running on public URL: https://aa341eebff76d4a920.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# "/usr/local/envs/GPTSoVITS/bin/python" -s GPT_SoVITS/prepare_datasets/1-get-text.py
# "/usr/local/envs/GPTSoVITS/bin/python" -s GPT_SoVITS/prepare_datasets/1-get-text.py
# 제목없음.mp3_0000000000_0000135680.wav
# 제목없음.mp3_0000135680_0000298880.wav
# mecab installed
# mecab installed
# 제목없음.mp3_0000298880_0000490560.wav
# 제목없음.mp3_0000490560_0000685760.wav
# 제목없음.mp3_0000685760_0000964160.wav
# 제목없음.mp3_0000964160_0001250880.wav
# 제목없음.mp3_0001250880_0001513280.wav
# 제목없음.mp3_0001513280_0001686720.wav
# 제목없음.mp3_0001686720_0001954240.wav
# 제목없음.mp3_0001954240_0002169600.wav
# 제목없음.mp3_0002169600_0002374400.wav
# ...

# %%
# AI 전용 환경에 부품을 직접 때려 넣습니다.
# !/usr/local/envs/GPTSoVITS/bin/python -m pip install torchcodec

# 부품이 잘 들어갔는지 확인합니다 (에러 없으면 성공)
# !/usr/local/envs/GPTSoVITS/bin/python -c "import torchcodec; print('설치 확인 완료!')"

# 에러 기록이 남은 찌꺼기 폴더를 강제로 지웁니다.
# !rm -rf /content/GPT-SoVITS/logs/MyEconomicVoice
# Out:
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 78.4 MB/s  0:00:00
# ...
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# 설치 확인 완료!
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)

# %%
# 1. 누락된 부품 설치
# !pip install torchcodec

# 2. 에러가 났던 찌꺼기 폴더 강제 삭제
# !rm -rf /content/GPT-SoVITS/logs/MyEconomicVoice
# Out:
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# ...
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)

# %%
# !rm -rf /content/GPT-SoVITS/logs/MyEconomicVoice
# Out:
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)

# %%
# !pip install torchcodec
# Out:
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# ...

# %%
# !pip install torchcodec
# Out:
# /bin/bash: /usr/local/lib/libtinfo.so.6: no version information available (required by /bin/bash)
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 67.1 MB/s eta 0:00:00
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
